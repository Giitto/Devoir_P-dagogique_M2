# %% [markdown]
# ##BARAKAT Khalid

# %% [markdown]
# #Importation de librairies

# %%
import numpy as np 
import matplotlib.pyplot as plt
from sklearn import *
from sklearn.datasets import fetch_openml
from sklearn.datasets.samples_generator import make_blobs

# %% [markdown]
# #Manipulation d'un jeu de données

# %%
iris = datasets.load_iris()

# %%
print(iris.data)
print(iris.feature_names)
print(iris.target_names)
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.  3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.4 3.7 1.5 0.2]
#  [4.8 3.4 1.6 0.2]
#  [4.8 3.  1.4 0.1]
#  [4.3 3.  1.1 0.1]
#  [5.8 4.  1.2 0.2]
#  [5.7 4.4 1.5 0.4]
#  [5.4 3.9 1.3 0.4]
#  [5.1 3.5 1.4 0.3]
#  [5.7 3.8 1.7 0.3]
#  [5.1 3.8 1.5 0.3]
#  [5.4 3.4 1.7 0.2]
#  [5.1 3.7 1.5 0.4]
#  [4.6 3.6 1.  0.2]
#  [5.1 3.3 1.7 0.5]
#  [4.8 3.4 1.9 0.2]
#  [5.  3.  1.6 0.2]
#  [5.  3.4 1.6 0.4]
#  [5.2 3.5 1.5 0.2]
#  [5.2 3.4 1.4 0.2]
#  [4.7 3.2 1.6 0.2]
#  [4.8 3.1 1.6 0.2]
#  [5.4 3.4 1.5 0.4]
#  [5.2 4.1 1.5 0.1]
#  [5.5 4.2 1.4 0.2]
#  [4.9 3.1 1.5 0.2]
#  [5.  3.2 1.2 0.2]
#  [5.5 3.5 1.3 0.2]
#  [4.9 3.6 1.4 0.1]
#  [4.4 3.  1.3 0.2]
#  [5.1 3.4 1.5 0.2]
#  [5.  3.5 1.3 0.3]
#  [4.5 2.3 1.3 0.3]
#  [4.4 3.2 1.3 0.2]
#  [5.  3.5 1.6 0.6]
#  [5.1 3.8 1.9 0.4]
#  [4.8 3.  1.4 0.3]
#  [5.1 3.8 1.6 0.2]
# ...

# %%
i = len(iris.target)
print(i)
for k in range(i):
  print(iris.target_names[iris.target[k]]," ",iris.data[k])
# Out:
# 150
# setosa   [5.1 3.5 1.4 0.2]
# setosa   [4.9 3.  1.4 0.2]
# setosa   [4.7 3.2 1.3 0.2]
# setosa   [4.6 3.1 1.5 0.2]
# setosa   [5.  3.6 1.4 0.2]
# setosa   [5.4 3.9 1.7 0.4]
# setosa   [4.6 3.4 1.4 0.3]
# setosa   [5.  3.4 1.5 0.2]
# setosa   [4.4 2.9 1.4 0.2]
# setosa   [4.9 3.1 1.5 0.1]
# setosa   [5.4 3.7 1.5 0.2]
# setosa   [4.8 3.4 1.6 0.2]
# setosa   [4.8 3.  1.4 0.1]
# setosa   [4.3 3.  1.1 0.1]
# setosa   [5.8 4.  1.2 0.2]
# setosa   [5.7 4.4 1.5 0.4]
# setosa   [5.4 3.9 1.3 0.4]
# setosa   [5.1 3.5 1.4 0.3]
# setosa   [5.7 3.8 1.7 0.3]
# setosa   [5.1 3.8 1.5 0.3]
# setosa   [5.4 3.4 1.7 0.2]
# setosa   [5.1 3.7 1.5 0.4]
# setosa   [4.6 3.6 1.  0.2]
# setosa   [5.1 3.3 1.7 0.5]
# setosa   [4.8 3.4 1.9 0.2]
# setosa   [5.  3.  1.6 0.2]
# setosa   [5.  3.4 1.6 0.4]
# setosa   [5.2 3.5 1.5 0.2]
# setosa   [5.2 3.4 1.4 0.2]
# setosa   [4.7 3.2 1.6 0.2]
# setosa   [4.8 3.1 1.6 0.2]
# setosa   [5.4 3.4 1.5 0.4]
# setosa   [5.2 4.1 1.5 0.1]
# setosa   [5.5 4.2 1.4 0.2]
# ...

# %%
print("Moyenne des valeur des données :",iris.data.mean())
print("Ecart type des données :",iris.data.std())
print("Valeur max des données :",iris.data.argmax())
print("Valeur min des données :",iris.data.argmin())
# Out:
# Moyenne des valeur des données : 3.4644999999999997
# Ecart type des données : 1.9738430577598278
# Valeur max des données : 524
# Valeur min des données : 39

# %%
k = iris.data.shape

print("Il y a",k[0]," données avec ",k[1],"variable et divisé en ",iris.target_names.size," classe différente")
# Out:
# Il y a 150  données avec  4 variable et divisé en  3  classe différente

# %% [markdown]
# #Telechargement et importation de données

# %%
mnist = fetch_openml('MNIST original')
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/datasets/openml.py:51: RuntimeWarning: Invalid cache, redownloading file
#   warn("Invalid cache, redownloading file", RuntimeWarning)
# ---------------------------------------------------------------------------
# InvalidURL                                Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/sklearn/datasets/openml.py in wrapper()
#      46             try:
# ---> 47                 return f()
#      48             except HTTPError:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/datasets/openml.py in _load_json()
#     150     def _load_json():
# --> 151         with closing(_open_openml_url(url, data_home)) as response:
#     152             return json.loads(response.read().decode("utf-8"))
#
# /usr/local/lib/python3.6/dist-packages/sklearn/datasets/openml.py in _open_openml_url(openml_path, data_home)
#      99         try:
# --> 100             with closing(urlopen(req)) as fsrc:
# ...

# %% [markdown]
# #Génération de données et affichage

# %% [markdown]
# Affichage de l'aide pour la fonction make blobs

# %%
help(make_blobs)
# Out:
# Help on function make_blobs in module sklearn.datasets.samples_generator:
#
# make_blobs(n_samples=100, n_features=2, centers=None, cluster_std=1.0, center_box=(-10.0, 10.0), shuffle=True, random_state=None)
#     Generate isotropic Gaussian blobs for clustering.
#
#     Read more in the :ref:`User Guide <sample_generators>`.
#
#     Parameters
#     ----------
#     n_samples : int or array-like, optional (default=100)
#         If int, it is the total number of points equally divided among
#         clusters.
#         If array-like, each element of the sequence indicates
#         the number of samples per cluster.
#
#     n_features : int, optional (default=2)
#         The number of features for each sample.
#
#     centers : int or array of shape [n_centers, n_features], optional
#         (default=None)
#         The number of centers to generate, or the fixed center locations.
#         If n_samples is an int and centers is None, 3 centers are generated.
# ...

# %% [markdown]
# Création d'une fonction qui utilise figure scatter title xlim ylim xlabel ylabel et show

# %%
def affichage(x,y,n,t):
  color = ['red','blue','green','yellow']
  plt.figure()
  plt.title(t)
  for i in range(n):
    plt.scatter(x[i,0],x[i,1],c = color[y[i]], s = 20)
  plt.xlim(-15,15)
  plt.ylim(-15,15)
  plt.xlabel('Features')
  plt.ylabel('Value')
  plt.show()

# %% [markdown]
# Génération de 1000 données de deux variables réparties en 4 groupes

# %%
a,b = make_blobs(n_samples = 1000, n_features = 2, centers = 4)
titre = 'Figure 1000'
affichage(a,b,b.size,titre)

# %% [markdown]
# Génération de 100 données de deux variables réparties en 2 groupes

# %%
a1,b1 = make_blobs(n_samples = 100, n_features = 2, centers = 2)
titre1 = 'Figure 100'
affichage(a1,b1,b1.size,titre1)

# %% [markdown]
# Génération de 500 données de deux variables répartie en 3 groupes

# %%
a2,b2 = make_blobs(n_samples = 500, n_features = 2, centers = 3)
titre2 = 'Figure 500'
affichage(a2,b2,b2.size,titre2)

# %% [markdown]
# Concaténation des deux jeux de données

# %%
ac,bc = np.vstack((a1,a2)), np.hstack((b1,b2))
titrec = titre1 + ' + '+titre2
affichage(ac,bc,bc.size,titrec)
